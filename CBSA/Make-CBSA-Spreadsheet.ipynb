# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv("zip07_cbsa06.txt", sep = ",", dtype="str")

# %%
data[:10]
# Out:
#     ZIP5 ZIP4   ZIP9 STATE CODE STATE COUNTY CODE     COUNTY NAME CBSA CODE  \
# 0  04841  NaN  04841         23    ME         013     Knox County     40500
# 1  04843  NaN  04843         23    ME         013     Knox County     40500
# 2  04846  NaN  04846         23    ME         013     Knox County     40500
# 3  04847  NaN  04847         23    ME         013     Knox County     40500
# 4  04848  NaN  04848         23    ME         027    Waldo County       NaN
# 5  04849  NaN  04849         23    ME         027    Waldo County       NaN
# 6  04850  NaN  04850         23    ME         027    Waldo County       NaN
# 7  04851  NaN  04851         23    ME         013     Knox County     40500
# 8  04852  NaN  04852         23    ME         015  Lincoln County       NaN
# 9  04853  NaN  04853         23    ME         013     Knox County     40500
#
#      CBSA TITLE                      CBSA LSAD METRO DIVISION CODE  \
# ...

# %%
newdata = data[['ZIP5', 'CBSA CODE', 'CBSA LSAD']]

# %%
newdata[:200]
# Out:
#       ZIP5 CBSA CODE                      CBSA LSAD
# 0    04841     40500  Micropolitan Statistical Area
# 1    04843     40500  Micropolitan Statistical Area
# 2    04846     40500  Micropolitan Statistical Area
# 3    04847     40500  Micropolitan Statistical Area
# 4    04848       NaN                            NaN
# 5    04849       NaN                            NaN
# 6    04850       NaN                            NaN
# 7    04851     40500  Micropolitan Statistical Area
# 8    04852       NaN                            NaN
# 9    04853     40500  Micropolitan Statistical Area
# 10   04854     40500  Micropolitan Statistical Area
# 11   04855     40500  Micropolitan Statistical Area
# 12   04856     40500  Micropolitan Statistical Area
# 13   04858     40500  Micropolitan Statistical Area
# 14   04859     40500  Micropolitan Statistical Area
# 15   04860     40500  Micropolitan Statistical Area
# 16   04861     40500  Micropolitan Statistical Area
# ...

# %% [markdown]
# As you can see, there is a ridiculous number of repetitions in `newdata` above, because we've filtered out many of the columns that would otherwise make entries unique. We'll now reduce `newdata` to a df of *unique* rows.

# %%
len(newdata)
# Out:
# 2820093

# %%
newdata.drop_duplicates(inplace=True)
len(newdata)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:1: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame
#   if __name__ == '__main__':
# 49289

# %%
# nice improvement! 98.25% deletion!
newdata[:10]
# Out:
#     ZIP5 CBSA CODE                      CBSA LSAD
# 0  04841     40500  Micropolitan Statistical Area
# 1  04843     40500  Micropolitan Statistical Area
# 2  04846     40500  Micropolitan Statistical Area
# 3  04847     40500  Micropolitan Statistical Area
# 4  04848       NaN                            NaN
# 5  04849       NaN                            NaN
# 6  04850       NaN                            NaN
# 7  04851     40500  Micropolitan Statistical Area
# 8  04852       NaN                            NaN
# 9  04853     40500  Micropolitan Statistical Area
#
# [10 rows x 3 columns]

# %%
newdata.to_csv("ZipToCBSA.csv", index=False)
